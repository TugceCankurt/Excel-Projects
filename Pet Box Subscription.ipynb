# %% [markdown]
# ## Data Validation
#
# The original data is 880 rows and 9 columns. At first, I started to validate the dataset according to the data set description. When checked, there was no duplicate row. I checked if there were any missing or hidden rows or columns. When I checked each column;
# - There were only unique product IDs, as expected.
# - There were 11 product categories, as expected.
# - The number format in the sales column was converted as requested.
# - The format in Price column was changed from General to Number.
# - Vendor ID is as expected.
# - Pet size is as expected.
# - I removed rows that contain "hamster" and "rabbit" as pet types which are 46 rows as requested.
# - Consumer's ratings are on 10 point scale as expected.
# - Rebuy column has only 1 or 0 as expected.

# %% [markdown]
# **How many products are being purchased more than once?**
#
# There were 833 items were purchased in this database. When we analyse products according to their rebuy information, I pointed out that 390 of them are being purchased more than once which amount is less than others.
#
# ![image.png](attachment:image.png)
#
# **Do the products being purchased again have better sales than others?**
#
# The products being purchased again have **worse** sales than others.
# Sales of the products being purchased again are 45.587.000 USD, whereas sales of others are 51.125.000 USD
#
# ![image-9](attachment:image-2.png)
#
# **What products are more likely to be purchased again for different types of pets?**
#
# Equipment, snacks, and toys are more likely to be purchased again for cats, fish and birds. According to analyse, we could include medicine in this list for dog. The Marketing team should take into consideration medical restrictions from the government.
# For each type of product category, products for dogs and cats are being purchased again more than others.
#
# ![image-8](attachment:image-3.png)
#
# Based on all of the above, I would suggest including some equipment, snacks and toys, especially for dogs and cats, in the products being purchased more than once. According to analysis, The products being purchased again have worse sales than others. Because of that, I can further analysis for the products purchased once.
